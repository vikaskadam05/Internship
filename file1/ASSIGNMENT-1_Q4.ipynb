# %%
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# # 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame-
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
soup=bs(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
# Top 10 Women Teams

team10=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    team10.append(i.text.replace('\n',''))

# %%
top_10_team=team10[:10]

# %%
top_10_team
# Out:
# ['Australia',
#  'England',
#  'South Africa',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Sri Lanka',
#  'Bangladesh',
#  'Thailand',
#  'Pakistan']

# %%
# Matches

matche1=[]
for i in soup.find_all('td',class_="rankings-block__banner--matches"):
    matche1.append(i.text)

# %%
matche1
# Out:
# ['21']

# %%
# Matches

matches=[]
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    matches.append(i.text)

# %%
match=matches[0:18:2]

# %%
match
# Out:
# ['23', '21', '18', '21', '20', '9', '14', '11', '24']

# %%
total_match=matche1+match

# %%
total_match
# Out:
# ['21', '23', '21', '18', '21', '20', '9', '14', '11', '24']

# %%
# Points

points1=[]
for i in soup.find_all('td',class_="rankings-block__banner--points"):
    points1.append(i.text)

# %%
points1
# Out:
# ['3,429']

# %%
points=matches[1:19:2]

# %%
points
# Out:
# ['2,991', '2,446', '1,745', '2,014', '1,768', '714', '1,074', '753', '1,602']

# %%
tota_points=points1+points

# %%
tota_points
# Out:
# ['3,429',
#  '2,991',
#  '2,446',
#  '1,745',
#  '2,014',
#  '1,768',
#  '714',
#  '1,074',
#  '753',
#  '1,602']

# %%
# Rating

rating1=[]
for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    rating1.append(i.text.replace('\n','').replace('                            ','').replace('                            ',''))

# %%
rating1
# Out:
# ['163']

# %%
N=9
rating9=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    rating9.append(i.text)
rat9=rating9[:N]

# %%
rat9
# Out:
# ['130', '116', '97', '96', '88', '79', '77', '68', '67']

# %%
total_rating=rating1+rat9

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'Top Team':top_10_team, 'Matches':total_match,'Points':tota_points,'Rating':total_rating})

# %%
df1
# Out:
#        Top Team Matches Points Rating
# 0     Australia      21  3,429    163
# 1       England      23  2,991    130
# 2  South Africa      21  2,446    116
# 3         India      18  1,745     97
# 4   New Zealand      21  2,014     96
# 5   West Indies      20  1,768     88
# 6     Sri Lanka       9    714     79
# 7    Bangladesh      14  1,074     77
# 8      Thailand      11    753     68
# 9      Pakistan      24  1,602     67

# %% [markdown]
# b) Top 10 women’s ODI Batting players along with the records of their team and rating

# %%
page1=requests.get('https://www.icc-cricket.comhttps//www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...
